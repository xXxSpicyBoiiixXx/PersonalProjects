# %%
import os
import math
import numpy as np
import scipy as sp
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#bmag = pd.read_csv('/Users/Astrophysics/data/B.csv')

# data in apparent magnitudes m
data = pd.read_csv('sukma.csv')

# Isochrones/models in absolute magnitudes M
iso1 = pd.read_csv('t1e8.csv')
iso2 = pd.read_csv('t1e9.csv')
iso3 = pd.read_csv('t2.5e8.csv')
iso4 = pd.read_csv('t3e9.csv')
iso5 = pd.read_csv('t5e8.csv')
iso6 = pd.read_csv('t7.5e8.csv')
iso7 = pd.read_csv('t7e9.csv')
iso8 = pd.read_csv('t10e9.csv')
iso9 = pd.read_csv('t13e9.csv')

# %%
# Distance modulus mu = m - M
mu = 12.

plt.figure(figsize=(5, 5))

# plot data

plt.plot(data['Bmag'] - data['Vmag'], data['Vmag'] ,'.')

# plot models
#plt.plot(iso1['Bmag']-iso1['Vmag'], iso1['Bmag'] + mu)
#plt.plot(iso2['Bmag']-iso2['Vmag'], iso2['Bmag'] + mu)
#plt.plot(iso3['Bmag']-iso3['Vmag'], iso3['Bmag'] + mu)
#plt.plot(iso4['Bmag']-iso4['Vmag'], iso4['Bmag'] + mu)
#plt.plot(iso5['Bmag']-iso5['Vmag'], iso5['Bmag'] + mu)
#plt.plot(iso6['Bmag']-iso6['Vmag'], iso6['Bmag'] + mu)
plt.plot(iso7['Bmag']-iso7['Vmag'], iso7['Bmag'] + mu)
plt.plot(iso8['Bmag']-iso8['Vmag'], iso8['Bmag'] + mu)
plt.plot(iso9['Bmag']-iso9['Vmag'], iso9['Bmag'] + mu)
plt.xlabel('B - V')
plt.ylabel('B')
plt.xlim(-5,10)
plt.ylim(25,10)
#plt.xlim(-2, 4)
# Out:
# (25, 10)

# %%
print('Distance to cluster:', round(10**(mu/5+1),1),'pc')
# Out:
# Distance to cluster: 2511.9 pc
